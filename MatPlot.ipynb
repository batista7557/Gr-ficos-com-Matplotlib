# %% [markdown]
# <a href="https://colab.research.google.com/github/batista7557/Gr-ficos-com-Matplotlib/blob/main/MatPlot.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Importação das bibliotecas

# %%
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# Desenhando uma linha diagonal em um gráfico

# %%
xpoints = np.array([0,6])
ypoints = np.array([0,250])

plt.plot(xpoints, ypoints)
plt.show()

# %% [markdown]
# Desenhando um gráfico com posições diferentes

# %%
xpoints = np.array([30,6])
ypoints = np.array([10,25])

plt.plot(xpoints, ypoints)
plt.show()

# %% [markdown]
# Gráfico sem linha

# %%
xpoints = np.array([1,8])
ypoints = np.array([3,10])

plt.plot(xpoints, ypoints, 'o')
plt.show()

# %% [markdown]
# Gráfico com múltiplos pontos

# %%
xpoints = np.array([1,2,6,8])
ypoints = np.array([3,8,1,10])

plt.plot(xpoints, ypoints)
plt.show()

# %% [markdown]
# Marcador

# %%
#Se não especificar os pontos do eixo 'x' por exemplo, ele irá seguir dos pontos 1,2,3... em ordem, sucessivamente
ypoints = np.array([3,8,1,10])

plt.plot(ypoints, marker='o')
plt.show()

# %%
#Substituindo por uma estrela
plt.plot(ypoints, marker='*')
plt.show()

# %% [markdown]
# Linha pontilhada e adicionando cores

# %%
#o - Pontos
#: - Linha pontilhada
#r - cor vermelha
plt.plot(ypoints, 'o:r')
plt.show()

# %%
#Alterando as dimensões dos pontos - ms
plt.plot(ypoints, marker = 'o', ms = 20)
plt.show()

# %%
#Cor do contorno do marcador - mec
plt.plot(ypoints, marker = 'o', ms = 20, mec = 'r')
plt.show()

# %%
#Cor do marcador - mfc
plt.plot(ypoints, marker = 'o', ms = 20, mfc = 'r')
plt.show()

# %% [markdown]
# Estilo da linha

# %%
#linestyle - pontilhada
plt.plot(ypoints, linestyle = 'dotted')
plt.show()

# %%
#linestyle - traços
plt.plot(ypoints, linestyle = 'dashed')
plt.show()

# %% [markdown]
# Cor da linha

# %%
plt.plot(ypoints, color = 'r')
plt.show()

# %% [markdown]
# Expessura da linha

# %%
plt.plot(ypoints, linewidth = '20.5')
plt.show()

# %% [markdown]
# Múltiplas linhas

# %%
y1 = np.array([3,8,1,10])
y2 = np.array([6,2,7,11])

plt.plot(y1)
plt.plot(y2)

plt.show()
